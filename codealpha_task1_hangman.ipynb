# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitKumarSingh-aks/codeAlpha_PythonProgramme/blob/main/codealpha_task1_hangman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def play_hangman():
    # Predefined list of 5 words
    words = ["python", "codealpha", "developer", "program", "terminal"]
    secret_word = random.choice(words)
    guessed_letters = set()
    incorrect_guesses = 0
    max_attempts = 6

    print("=" * 40)
    print("      WELCOME TO CODEALPHA HANGMAN      ")
    print("=" * 40)
    print(f"Guess the word! You have {max_attempts} incorrect attempts allowed.\n")

    while incorrect_guesses < max_attempts:
        # Display current word status
        display_word = [letter if letter in guessed_letters else "_" for letter in secret_word]
        print("Current Word: " + " ".join(display_word))
        print(f"Attempts left: {max_attempts - incorrect_guesses}")
        print(f"Guessed letters: {', '.join(sorted(guessed_letters)) if guessed_letters else 'None'}\n")

        # Win condition check
        if "_" not in display_word:
            print("vCONGRATULATIONS! You guessed the word correctly:", secret_word)
            break

        # User Input Processing
        guess = input("Enter a single letter: ").lower().strip()

        if len(guess) != 1 or not guess.isalpha():
            print(" Invalid input! Please enter a single alphabetical character.\n")
            continue

        if guess in guessed_letters:
            print(f" You already guessed '{guess}'. Try another letter.\n")
            continue

        guessed_letters.add(guess)

        if guess in secret_word:
            print(f"Good job! '{guess}' is in the word.\n")
        else:
            incorrect_guesses += 1
            print(f" Sorry, '{guess}' is not in the word.\n")

    if incorrect_guesses == max_attempts:
        print("=" * 40)
        print(f"GAME OVER! The correct word was: '{secret_word}'")
        print("=" * 40)

if __name__ == "__main__":
    play_hangman()
# Out:
# ...
#       WELCOME TO CODEALPHA HANGMAN
# ...
# Guess the word! You have 6 incorrect attempts allowed.
#
# Current Word: _ _ _ _ _ _ _ _ _
# Attempts left: 6
# Guessed letters: None
#
# Enter a single letter: e
# Good job! 'e' is in the word.
#
# Current Word: _ _ _ e _ _ _ _ _
# Attempts left: 6
# Guessed letters: e
#
# Enter a single letter: a
# Good job! 'a' is in the word.
#
# Current Word: _ _ _ e a _ _ _ a
# Attempts left: 6
# Guessed letters: a, e
#
# Enter a single letter: l
# Good job! 'l' is in the word.
#
# Current Word: _ _ _ e a l _ _ a
# Attempts left: 6
# Guessed letters: a, e, l
#
# Enter a single letter: d
# Good job! 'd' is in the word.
#
# Current Word: _ _ d e a l _ _ a
# Attempts left: 6
# Guessed letters: a, d, e, l
#
# Enter a single letter: c
# Good job! 'c' is in the word.
#
# Current Word: c _ d e a l _ _ a
# Attempts left: 6
# Guessed letters: a, c, d, e, l
#
# Enter a single letter: o
# Good job! 'o' is in the word.
#
# Current Word: c o d e a l _ _ a
# ...
